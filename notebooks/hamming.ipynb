# %% [markdown]
# # `hamming` module test

# %%
from mesomath.hamming import hamming, genCSV

print(hamming(1, 63))
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 10, 12, 15, 16, 18, 20, 24, 25, 27, 30, 32, 36, 40, 45, 48, 50, 54, 60, 64, 72, 75, 80, 81, 90, 96, 100, 108, 120, 125, 128, 135, 144, 150, 160, 162, 180, 192, 200, 216, 225, 240, 243, 250, 256, 270, 288, 300, 320, 324, 360, 375, 384, 400, 405]

# %%
print(hamming(1691)[0])
# Out:
# 2125764000

# %%
print(hamming(1000000)[0])
# Out:
# 519312780448388736089589843750000000000000000000000000000000000000000000000000000000

# %%
genCSV(63)
# Out:
# 1,1,01,1,1,01
# 2,2,02,1,30,30
# 3,3,03,1,20,20
# 4,4,04,1,15,15
# 5,5,05,1,12,12
# 6,6,06,1,10,10
# 7,8,08,1,450,07:30
# 8,9,09,1,400,06:40
# 9,10,10,1,6,06
# 10,12,12,1,5,05
# 11,15,15,1,4,04
# 12,16,16,1,225,03:45
# 13,18,18,1,200,03:20
# 14,20,20,1,3,03
# 15,24,24,1,150,02:30
# 16,25,25,1,144,02:24
# 17,27,27,1,8000,02:13:20
# 18,30,30,1,2,02
# 19,32,32,1,6750,01:52:30
# 20,36,36,1,100,01:40
# 21,40,40,1,90,01:30
# 22,45,45,1,80,01:20
# 23,48,48,1,75,01:15
# 24,50,50,1,72,01:12
# 25,54,54,1,4000,01:06:40
# 26,64,01:04,2,3375,56:15
# 27,72,01:12,2,50,50
# 28,75,01:15,2,48,48
# 29,80,01:20,2,45,45
# 30,81,01:21,2,160000,44:26:40
# 31,90,01:30,2,40,40
# 32,96,01:36,2,2250,37:30
# 33,100,01:40,2,36,36
# 34,108,01:48,2,2000,33:20
# 35,125,02:05,2,1728,28:48
# 36,128,02:08,2,101250,28:07:30
# 37,135,02:15,2,1600,26:40
# 38,144,02:24,2,25,25
# 39,150,02:30,2,24,24
# 40,160,02:40,2,1350,22:30
# 41,162,02:42,2,80000,22:13:20
# 42,192,03:12,2,1125,18:45
# 43,200,03:20,2,18,18
# ...
